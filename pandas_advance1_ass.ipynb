# %% [markdown]
# Q1. List any five functions of the pandas library with execution.
# 1. read_csv()
# This function is used to read a CSV file into a DataFrame.
# import pandas as pd
# me
# df = pd.read_csv('data.csv')
# print(df.head())  # Display the first 5 rows of the DataF
#
# 2. describe()
# This function generates descriptive statistics of the DataFrame, such as mean, standard deviation, and more.
# data = {
#     'A': [1, 2, 3, 4, 5],
#     'B': [5, 6, 7, 8, 9]
# }
# df = pd.DataFrame(dtistics
# print(df.des
#
# 3. groupby()
# This function is used to group data by a specific column and apply aggregate functions.
# data = {
#     'Category': ['A', 'A', 'B', 'B'],
#     'Values': [10, 20, 30, 40]
# }
# df = pd.DataFrame(dhe mean
# grouped_df = df.groupby('Category').mean()
# print(gro
# 4. drop()
# This function is used to remove specified labels from rows or columns.
# data = {
#     'A': [1, 2, 3, 4],
#     'B': [5, 6, 7, 8],
#     'C': [9, 10, 11, 12]
# }
# df = pd.DataFramelumn 'B'
# df_dropped = df.drop('B', axis=1)
# print(df
# 5. fillna()
# This function is used to fill NA/NaN values using a specified method.
# data = {
#     'A': [1, 2, None, 4],
#     'B': [5, None, 7, 8]
# }
# df = pd.DataFrame(dd value
# df_filled = df.fillna(0)
# print(df_filled)
# _dropped)
# uped_df)
# ribe())
# ame

# %% [markdown]
# Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the
# DataFrame with a new index that starts from 1 and increments by 2 for each row
# import pandas as pd
#
# def reindex_dataframe(dfy 2
#     new_index = range(1, 1 + 2 * len(df)index
#     df_reindexed = df.copy()
#     df_reindexed.index = new_index
#     return df_re DataFrame
# data = {
#     'A': [10, 20, 30, 40],
#     'B': [50, 60, 70, 80],
#     'C': [90, 100, 110, 120]
# }
# df = pd.xing the DataFrame
# df_reindexed = reindex_dataframe(df)
# print(df_reindexed)
# .

# %% [markdown]
# Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that
# iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The
# function should print the sum to the consol
# import pandas as pd
#
# def sum_first_three_values(dfsts
#     if 'Values' not in df.columns:
#         print("The DataFrame does not have a 'Values' column.")
#         r' column
#     sum_values = df['Values'].iloc[:3].sum()
#    tothe console
#     print(f"The sum of the first three values in the 'Values' column is: {Sample DataFrame
# data = {
#     'Values': [5, 10, 15, 20, 25]
# }
# df =the first three values
# sum_first_three_values(df)
#
# e.

# %% [markdown]
# Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column
# 'Word_Count' that contains the number of words in each row of the 'Text' column
# import pandas as pd
#
# def add_word_count_column(dfsts
#     if 'Text' not in df.columns:
#         print("The DataFrame does not have a 'Text' column.")
#         rnt words
#     df['Word_Count'] = df['Text'].apply(lambda x: len(str(x).split()))
#
#    ple DataFrame
# data = {
#     'Text': ['This is a sentence.', 'Another sentence here.', 'And one more for good measure.']
# }
# df = pd'Word_Count' column
# df = add_wo the updated DataFrame
# print(df)
# .

# %% [markdown]
# Q5. How are DataFrame.size() and DataFrame.shape() different?
# DataFrame.size:
#  This attribute returns an integer representing the total number of elements in the DataFrame. It is equivalent to the number of rows multiplied by the number of columns.
#  import pandas as pd
#
# data = {'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]}
# df = pd.DataFrame(data)
#
# print(df.size)  # Outp
#
# DataFrame.shape:
#  This attribute returns a tuple representing the dimensionality of the DataFrame. The first element of the tuple is the number of rows, and the second element is the number of columns.utimport pandas as pd
#
# data = {'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]}
# df = pd.DataFrame(data)
#
# print(df.shape)  # Output: (
#
# DataFrame.size gives you the total number of elements in the DataFrame.
# DataFrame.shape gives you the number of rows and columns as a 3, 3)
# : 9

# %% [markdown]
# Q6. Which function of pandas do we use to read an excel file?
# To read an Excel file into a Pandas DataFrame, you can use the pandas.read_excel() function. Here is an example of how to use it:
# import pandas as pd
#
# # Read the Excel file
# df = pd.read_excel('path_to_your_file.xlsxFrame
# print(df)

# %% [markdown]
# Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email
# addresses in the format 'username@domain.com'. Write a Python function that creates a new column
# 'Username' in df that contains only the username part of each email address.
# The username is the part of the email address that appears before the '@' symbol. For example, if the
# email address is 'john.doe@example.com', the 'Username' column should contain 'john.doe'. Your
# function should extract the username from each email address and store it in the new 'Username'
# column.
# import pandas as pd
#
# def extract_username(df):
#     df['Username'] = df['Email'].apply(lambda x: x.split('@')[0])
#     returnusage:
# data = {'Email': ['john.doe@example.com', 'jane.smith@domain.com', 'user123@service.net']}
# df = pd.DataFram usernames
# df = extract_usthe DataFrame
# print(df)

# %% [markdown]
# Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects
# all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The
# function should return a new DataFrame that contains only the selected rows.
# For example, if df contains the following values:
# A B C
# 0 3 5 1
# 1 8 2 7
# 2 6 9 4
# 3 2 3 5
# 4 9 1 2
# import pandas as pd
#
# def select_rows(df 10
#     selected_df = df[(df['A'] > 5) & (df['B'] < 10)]
#     return selecte usage:
# data = {
#     'A': [3, 8, 6, 2, 9],
#     'B': [5, 2, 9, 3, 1],
#     'C': [1, 7, 4, 5, 2]
# }
# df = pd.Datd on conditions
# selected_df =  the selected rows
# print(selected_df)

# %% [markdown]
# Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean,
# median, and standard deviation of the values in the 'Values' column
# import pandas as pd
#
# def calculate_statistics(dfean
#     mean_value = df['Values'].mean()
# median
#     median_value = df['Values'].median()
#    rddeviation
#     std_dev_value = df['Values'ted statistics
#     return mean_value, median_value,
# # Example usage:
# data = {
#     'Values': [10, 20, 30, 40, 50]
# }
# df = pd.DataFrame(data)
#
# mean_value, median_value, std_dev_value = calculate_statistics(df)
#
# print("Mean:", mean_value)
# print("Median:", median_value)
# print("Standard Deviation:", std_dev_value)
# .

# %% [markdown]
# Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to
# create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days
# for each row in the DataFrame. The moving average should be calculated using a window of size 7 and
# should include the current d
#
# import pandas as pd
#
# def calculate_moving_average(dfmat
#     df['Date'] = pd.to_datetime(df['Date'])
# 'Date'
#     df = df.sort_values(by='Datesize of 7
#     df['MovingAverage'] = df['Sales'].rolling(window=7, min_periods=1).mean()
#
#   Example usage:
# data = {
#     'Date': ['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04', '2024-01-05',
#              '2024-01-06', '2024-01-07', '2024-01-08', '2024-01-09', '2024-01-10'],
#     'Sales': [100, 150, 200, 250, 300, 350, 400, 450, 500, 550]
# }
# df =ate the moving average
# df_with_moving_avg = calculate_moving_average(df)
#
# print(df_with_moving_avg)
#
# ay.

# %% [markdown]
# Q11. You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new
# column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g.
# Monday, Tuesday) corresponding to each date in the 'Date' column.
# For example, if df contains the following values:
# Date
# 0 2023-01-01
# 1 2023-01-02
# 2 2023-01-03
# 3 2023-01-04
# 4 2023-01-05
# Your function should create the following DataFrame:
#
# Date Weekday
# 0 2023-01-01 Sunday
# 1 2023-01-02 Monday
# 2 2023-01-03 Tuesday
# 3 2023-01-04 Wednesday
# 4 2023-01-05 Thursday
# The function should return the m
#
# import pandas as pd
#
# def add_weekday_column(dfmat
#     df['Date'] = pd.to_datetime(df['Date'])
#  names
#     df['Weekday'] = df['Date'].dt.day_name()
#
#     rmple usage:
# data = {
#     'Date': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05']
# }
# df = pd.D 'Weekday' column
# df_with_weekday = add_weekday_column(df)
#
# print(df_with_weekday)
# odified DataFrame.

# %% [markdown]
# Q12. Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Python
# function to select all rows where the date is between '2023-01-01' and '2023-01-31'
# import pandas as pd
#
# def filter_date_range(df, start_date, end_datemat
#     df['Date'] = pd.to_datetime(df['Date'])
#  range
#     mask = (df['Date'] >= start_date) & (df['Date'] <= end the mask
#     filtered_df = df[mask]
#
#     return Example usage:
# data = {
#     'Date': ['2023-01-01', '2023-01-15', '2023-02-01', '2023-01-25', '2023-03-01'],
#     'Value': [10, 20, 30, 40, 50]
# }
# df = -01' and '2023-01-31'
# filtered_df = filter_date_range(df, '2023-01-01', '2023-01-31')
#
# print(filtered_df)

# %% [markdown]
# Q13. To use the basic functions of pandas, what is the first and foremost necessary library that needs to
# be imported
# To use the basic functions of pandas, the first and foremost necessary library that needs to be imported is pandas itself. You can import it using the following code:
# import pandas as pd
# ?
