# %% [markdown]
# Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the
# dataset have?
# import pandas as pd
# et
# file_path = '/mnt/data/flight_price.xlsx'
# df = pd.read_excel(file_path)
#
# # Check the dimensions of the dataset
# rows, columns = df.shape
# print(f"The dataset has {rows} rows and {columns} columns.")
#
#  management team?

# %% [markdown]
# Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the distribution.
# import matplotlib.pyplot as plt
#
# # Plot the histogram of flight prices
# plt.figure(figsize=(10, 6))
# plt.hist(df['Price'], bins=30, color='skyblue', edgecolor='black')
# plt.title('Distribution of Flight Prices')
# plt.xlabel('Price')
# plt.ylabel('Frequency')
# plt.grid(True)
# plt.show()

# %% [markdown]
# Q3. What is the range of prices in the dataset? What is the minimum and maximum price?
# # Calculate the minimum and maximum price
# min_price = df['Price'].min()
# max_price = df['Price'].max()
#
# print(f"The minimum price is {min_price}.")
# print(f"The maximum price is {max_price}.")

# %% [markdown]
# Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different
# airlines.
# # Create a boxplot to compare flight prices by airline
# plt.figure(figsize=(12, 6))
# df.boxplot(column='Price', by='Airline', grid=False, rot=45, fontsize=10)
# plt.title('Flight Prices by Airline')
# plt.suptitle('')  # Suppress the automatic title
# plt.xlabel('Airline')
# plt.ylabel('Price')
# plt.show()

# %% [markdown]
# Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how
# they may impact your analysis.
# plt.figure(figsize=(10, 6))
# plt.boxplot(df['Price'], vert=False)
# plt.title('Boxplot of Flight Prices')
# plt.xlabel('Price')
# plt.show()
#
#  Outliers can affect the analysis by skewing the mean and impacting model performance.

# %% [markdown]
# Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset
# to identify the peak travel season. What features would you analyze to identify the peak season, and how
# would you present your findings to your boss?
#
# df['Month'] = pd.to_datetime(df['Date']).dt.monthice
# average_price_by_month = df.groupby('Month')['Price'].mea month
# plt.figure(figsize=(10, 6))
# average_price_by_month.plot(kind='bar', color='lightcoral')
# plt.title('Average Flight Price by Month')
# plt.xlabel('Month')
# plt.ylabel('Average Price')
# plt.grid(True)
# lt.show()
#
# # Peak travel season would be identified by higher average prices in certain months.

# %% [markdown]
# Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight
# Price dataset to identify any trends in flight prices. What features would you analyze to identify these
# trends, and what visualizations would you use to present your findings to your team?
#
# df['Date'] = pd.to_datetime(df['Date'])
#
# average_price_over_time = df.resample('W', on='Date')['Price'].mean()
#
# plt.figure(figsize=(10, 6))
# average_price_over_time.plot(color='green')
# plt.title('Trend of Flight Prices Over Time')
# plt.xlabel('Date')
# plt.ylabel('Average Price')
# plt.grid(True)
# plt.show()

# %% [markdown]
# Q8. You are a data scientist working for an airline company, and you have been asked to analyze the
# Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to
# identify these factors, and how would you present your findings to the management team?# To identify factors affecting flight prices, you can analyze features like Airline, Source, Destination, etc.
# import seaborn as snsice
# plt.figure(figsize=(10, 6))
# sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# plt.title('Correlation Matrix of Features')
# plt.sw()
#
# # Use other techniques like feature importance from models to identify key factors.

# %% [markdown]
# Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does
# the dataset have?import pandas as pdRL
# url = "https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv"
# playstore_df = pd.read_csv(uataset
# rows, columns = playstore_df.shape
# print(f"The dataset has {rows} rows and {columns} columns.")
#  the company?

# %% [markdown]
# Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different
# app categories.
# import matplotlib.pyplot as plt
# ry
# plt.figure(figsize=(14, 8))
# playstore_df.boxplot(column='Rating', by='Category', grid=False, rot=90, fontsize=10)
# plt.title('App Ratings by Category')
# plt.suptitle('')  # Suppress the automatic title
# plt.xlabel('Category')
# plt.ylabel('Rating')
# plt.show()

# %% [markdown]
# Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may
# impact your analysis.
#
# missing_values = playstore_df.isnull().sum()
# print("Missing values in each column:")
# print(missing_value
#
#
# # Missing values can impact analysis by reducing the accuracy of models or leading to biased results.

# %% [markdown]
# Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize
# the relationship.
# playstore_df['Size'] = playstore_df['Size'].replace('Varies with device', pd.NA)
# playstore_df['Size'] = playstore_df['Size'].str.replace('M', '').str.replace('k', '').astype(float)
# playstore_df['Size'] = playstore_df['Size'] * playstore_df['Size'].apply(lambda x: 1 if pd.isna(x) else (1000 if x < 100 else 1ating
# plt.figure(figsize=(10, 6))
# plt.scatter(playstore_df['Size'], playstore_df['Rating'], alpha=0.5, color='purple')
# plt.title('Relationship between App Size and Rating')
# plt.xlabel('Size (in MB)')
# plt.ylabel('Rating')
# plt.grid(True)
# plt.show()

# %% [markdown]
# Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.
# # Convert 'Price' column to numeric by removing '$'
# playstore_df['Price'] = playstore_df['Price'].str.replace('$', '').astype(float)
#
# # Calculate average price by type
# average_price_by_type = playstore_df.groupby('Type')['Price'].mean()
#
# # Bar chart of average prices by app type
# plt.figure(figsize=(10, 6))
# average_price_by_type.plot(kind='bar', color='orange')
# plt.title('Average Price by App Type')
# plt.xlabel('App Type')
# plt.ylabel('Average Price')
# plt.grid(True)
# plt.show()

# %% [markdown]
# Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps
# with the highest number of installs.
# # Convert 'Installs' column to numeric by removing '+' and ','
# playstore_df['Installs'] = playstore_df['Installs'].str.replace('+', '').str.replace(',', '').astype(int)
#
# # Identify the top 10 most popular apps by installs
# top_10_apps = playstore_df[['App', 'Installs']].sort_values(by='Installs', ascending=False).head(10)
#
# print("Top 10 most popular apps by number of installs:")
# print(top_10_apps)

# %% [markdown]
# Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze the
# Google Playstore dataset to identify the most popular app categories. How would you approach this
# task, and what features would you analyze to make recommendations to the company?
# # Analyze the 'Category' and 'Installs' columns to identify the most popular categories
# category_installs = playstore_df.groupby('Category')['Installs'].sum().sort_values(ascending=False)
#
# # Bar chart of total installs by category
# plt.figure(figsize=(14, 8))
# category_installs.plot(kind='bar', color='blue')
# plt.title('Total Installs by App Category')
# plt.xlabel('Category')
# plt.ylabel('Total Installs')
# plt.grid(True)
# plshow()
#
# # Approach: Analyzing 'Category' and 'Installs' features to recommend the most popular app categories to the company.

# %% [markdown]
# Q16. A mobile app development company wants to analyze the Google Playstore dataset to identify the
# most successful app developers. What features would you analyze to make recommendations to the
# company, and what data visualizations would you use to present your findings?
#
# developer_installs = playstore_df.groupby('Developer')['Installs'].sum().sort_values(ascending=False).head(10)
#
# # Bar chart of total installs by developer
# plt.figure(figsize=(14, 8))
# developer_installs.plot(kind='bar', color='teal')
# plt.title('Top 10 Developers by Total Installs')
# plt.xlabel('Developer')
# plt.ylabel('Total Installs')
# plt.grid(True)
# pby developer
# developer_stats = playstore_df.groupby('Developer').agg({'Installs': 'sum', 'Rating': 'mean'})
# plt.figure(figsize=(10, 6))
# plt.scatter(developer_stats['Installs'], developer_stats['Rating'], alpha=0.5, color='blue')
# plt.title('Average Rating vs. Number of Installs by Developer')
# plt.xlabel('Total Installs')
# plt.ylabel('Average Rating')
# plt.grid(True)
# plt.show()

# %% [markdown]
# Q17. A marketing research firm wants to analyze the Google Playstore dataset to identify the best time to
# launch a new app. What features would you analyze to make recommendations to the company, and
# what data visualizations would you use to present your findings?
# playstore_df['Last Updated'] = pd.to_datetime(playstore_df['Last Updated'])
# playstore_df['Month'] = playstore_df['Last Updated'].dt.month
# playstore_df['Year'] = playstore_df['Last Updated'].dt.yr
# ends
# monthly_installs = playstore_df.groupby(['Year', 'Month'])['Installs']v
# er time
# monthly_installs.plot(figsize=(12, 6))
# plt.title('Total Installs Over Time')
# plt.xlabel('Time')
# plt.ylabel('Total Installs')
# plt.grid(Truenth and category
# import seaborn as sns
# category_monthly_installs = playstore_df.pivot_table(index='Category', columns='Month', values='Installs', aggfunc='sum')
# plt.figure(figsize=(12, 8))
# sns.heatmap(category_monthly_installs, cmap='coolwarm', annot=True, fmt='g')
# plt.title('Heatmap of Installs by Month and C average rating by month
# monthly_ratings = playstore_df.groupby(['Year', 'Month'])['Rating'].mean()
# monthly_ratings.plot(figsize=(12, 6), color='purple')
# plt.title('Average Rating Over Time')
# plt.xlabel('Time')
# plt.ylabel('Average Rating)
# plt.grid(True)
# plt.show()
# id(True)
# plt.show()
