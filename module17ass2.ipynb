# %% [markdown]
# # Q1: What is Estimation Statistics? Explain point estimate and interval estimate.
#
# Estimation statistics involves making inferences about population parameters based on sample data. There are two main types of estimates: point estimates and interval estimate
# - **Point Esmate**: A single value that serves as an estimate of a population parameter. For example, the sample mean (\(\bar{x}\)) is a point estimate of the population mean (\(\m
#
# - **Interval timate**: A range of values within which the population parameter is expected to lie with a certain level of confidence. For example, a 95% confidence interval for the population mean might be from 455.
#
# ### Q2: Write a Python function to estimate the population mean using a sample mean and standard deviation.
#
# Here is a Python function to estimate the population mean using the sample mean and standard:
#
# ```python
# import math
#
# def estimate_population_mean(sample_mean, sample_std_dev, sample_size):
#     standard_error = sample_std_dev / math.sqrt(sample_size)
#     return sample_mor
#
# # Example usage
# sample_mean = 50
# sample_std_dev = 10
# sample_size = 30
#
# mean, std_error = estimate_population_mean(sample_mean, sample_std_dev, sample_size)
# print(f"Estimated Population Mean: {mean}")
# print(f"Sta: {std_error}")
# ```
#
# ### Q3: What is Hypothesis Testing? Why is it used? State the impoance of Hypothesis sting.
#
# **Hypothesis Testing** is a statistical method used to make decisions about the properties of a population based on sample data. It is used to test the validity of a claim or hypothesiabout a population parameter.
#
# *Itance of Hypothis Testing**:
# - **Decision Making**: It helps in maki
# formed decisions bad on data.
# - **Scientific Research**: It is fundamental in scientific rrch to test theies and models.
# - **Quality Control**: It is used in manufacturing and uction to ensurproduct quality.
# - **Medical Studies**: It is used to test the effy of treatments or interventions.
#
# ### Q4: Create a hypothesis that states whether the average weight of male college students is greater than the avege weight of female colle students.
#
# **Null Hypothesis (\(H_0\))**: The average weight of male college students is equal to the average weight of female clege students.
# \[ H_0: \mu_m = u_f \]
#
# **Alternative Hypothesis (\(H_1\))**: The average weight of male college students is greater than the average weight of fem
# alollege students.
# \[ H_1: \mu_m > \mu_f \]
#
# ### Q5: Write a Python script to conduct a hypothesis test on the difference between two popula, given a sample from each po``python
# import scipy.stats as stats
#
# # Sample data
# male_weights = [70, 72, 68, 75, 78, 74, 71, 73, 76, 72]
# fe3, 62]
#
# # Calculate sample means and standard deviations
# mean_male = sum(male_weights) / len(male_weights)
# mean_female = sum(female_weights) / len(female_weights)
# std_male = statts)
# std_female = stats.tstd(female_weights)
#
# # Perform t-test
# t_stat, p_value = stats.ttest_ind(male_weights, female_weights, equal_var=Fal
#
# nt(f"T-statistic: {t_stat}")
# print(f"P-value: {p_value}")
# ```
#
# # Q6: What is a null and anative hypothesis? Give some examples.
#
# **Null Hypothesis (\(H_0\))**: The hypothesis that there is no effect or noifference. It is the hypothesis at researchers aim to test against.
#
# **Alternative Hypothesis (\(H_1\))**: The hypothesis thatffecor a differen. It is what researchers want to prove.
#
# **Examples**:
# 1. **Medical Study**:
#    - \(H_0\): The new drug has no effect on tients.
#    -(H_1\): The new drug has a positive effect on patients.
#
# 2. **Manufacturing**:
#    - \(H_0\): The mean diameter of produced widgetis 5 cm.
#   - \(H_1\): The mean diameter of produced widgets is not 5 cm.
#
# 3. **Education**:
#    - \(H_0\): The average test scores of students who attended online classes are equal to those who attended in-person classes.
#    - \(H_1\): The average test scores of studentho attended online classes are different from those who attend in-person classes.
# ### Q7: Write down the steps involved in hypothesis testing.
#
# 1. **State the potheses**: Define the null hothesis (\(H_0\)) and alternative hypothesis (\(H_1\)).
# 2. **Choose thSignificanceevel**: Decide the significan level (\(\alpha), commonly set at 0.05.
# 3. **Collect Data**: ther the sampleata.
# 4. **Perform the Test**: Calculate the test statistic and p-value.
# 5. **Make a Decision**:
#    - If palue \(\leq \alph), reject \(H_0\).
#    - If p-value > \(\alpha\fail to reject \(H_0\).
# 6. **Interpret Results**: Draw conclusions basedn the tt results.
#
# ### Q8: Define p-value and explain its significance in hypothesis testing.
#
# **P-value**: The probability of observing the test results, or something more extreme, asming the nulhyesis is true. It measures thetrength of evidence against the null hypothesis.
#
# **Significance**:
# - **Low P-v
# (\(\leq \alpha\))**: Indicas strong evidence against the null hypothesis, leading to its rejection.
# - **High P-value (\alpha\))**: Indicates weak evidence against the null hypothesis, leading to a failure to reject it.
#
# ### Q9: Generate a Studetribution plot using Python's matplotlib library, with the degrees of freedom parameter set to 10.
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
# import scipy.stats as stats
#
# df = 10
# x = np.linspace(-5, 5, 100)
# y = stats.t.pdf(x, df)
#
# plt.plot(x, y, 'b-', label=f'Student\'s t-distribution (df={df})')
# plt.title('Student\'s tsttion with 10 degrees of freedom')
# plt.xlabel('Value')
# plt.ylabel('Probability Density')
# plt.legend()
# plt.show()
# ```
#
# ### Q10: Write a Python program to calculate the two-sample t-ndependent samples, given two random samples of is that the population means are equal.
#
# ```python
# import numpy as np
# import scipy.stats as sm samples
# np.random.seed(0)
# sample1 = np.random.normal(50, 10, 30)
# sample2 = np.random.normal(55, 10, 30)
#
# # Pt
# t_stat, p_value = stats.ttest_ind(sample1, sample2)
#
# print(f"T-statistic: {t_stat}")
# print(f"P-value: {p_value}")
#
# # Interpret the result
# alpha = 0.05
# if p_valuare equal).")
# ```
#
# These answers provide a comprehensive overview of the concepts and methods related to hypothesis testing and estimation statistics.

# %% [markdown]
# Q11: What is Student’s t-distribution? When to use the t-Distribution?
# **Student’s t-distributi** is a probability distribution used in statistics that is similar to the normal distribution but has heavier tails. It is used when estimating population parameters when the sample size is small, and/or the population variance is unknown.
# **When to use the t-Distribuon**:
# - When the sample size is small (n < 30).
# - When the population standard deviation is unknown.
# - When the sample is drawn from a normally distributed population or the central limit theorem can be app.
#
# ### Q12: What is t-statistic? State the formula for t-statist.
#
# The ** tatistic** is a type of standardized test statistic used in hypothesis testing, specifically for small sample sizes or unknown population standard d-statistic**:
#
# For a single sample:
# \[ t = \frac{\bar{x} - \mu}{s / \sqrt{n}} \]
#
# Where:
# - \(\bar{x}\) = sample mean
# - \(\mu\) = population mean
# - \(s\) = sample standard deviation
#
#
#  \) = sample size
#
# ### Q13: Estimate the population mean revenue with a 95% confidence interval.
#
# Given:
# - Sample mean (\(\bar{x}\)) = $500
# - Sample standard deviation (s) = $50
# - Sample size (n) = 50
#
# First, we find the critical value (t*) for a 95% confidencewith \(df = n - 1\).
#
# ```python
# import scipy.stats as stats
#
# sample_mean = 500
# sample_std_dev = 50
# sample_size = 50
# confidence_level = 0.95
# alpha = 1 - confidence_level
#
# t_critical = stats.t.ppf(1 - alpha/2, df=sample_size-1)
# standard_error = sample_std_dev / (sample_size ** 0.5)
# margin_of_error = t_critical * standard_error
#
# confidence_interval = (sample_mean - margin_of_error, sampecerval
# ```
#
# Output:
# \[ (485.06, 514.94) \]
#
# ### Q14: Test the hypothesis that a new drug decreases blood pressure by 10 mmHg.
#
# Given:
# - Sample mean (\(\bar{x}\)) = 8 mmHg
# - Population mean (\(\mu\)) = 10 mmHg
# - Sample standard deviation (s) = 3 mmHg
# - Sample size (n) = 100
# - Significance level (\(\alpha\
#
# First, we calculate the t-statistic and p-value.
#
# ```python
# import scipy.stats as stats
#
# sample_mean = 8
# population_mean = 10
# sample_std_dev = 3
# sample_size = 100
# alpha = 0.05
#
# t_statistic = (sample_mean - population_mean) / (sample_std_dev / (sample_size ** 0.5))
# p_value ats.t.sf(abs(t_statistic), df=sample_size-1) * 2
#
# t_statistic, p_value
#
#
# If the p-value is less than \(\alpha\), we reject the null hypothesis.
#
# ### Q15: Test the hypothesis that the true mean weight of the products is less than 5 pounds.
#
# Given:
# - Sample mean (\(\bar{x}\)) = 4.8 pounds
# - Population mean (\(\mu\)) = 5 pounds
# - Sample standard devia 0.5 pounds
# - Sample size (n) = 25
# - Significance level (\(\alpha\)) = 0.01
#
# ```python
# sample_mean = 4.8
# population_mean = 5
# sample_std_dev = 0.5
# sample_size = 25
# alpha = 0.01
#
# t_statistic = (sample_mean - population_mean) / (sample_std_dev /mple_size ** 0.5))
# p_value = stats.t.cdf(t_statistic, df=sample_size-1)
#
# statistic, p_value
# ```
#
# If the p-value is less than \(\alpha\), we reject the null hypothesis.
#
# ### Q16: Test the hypothesis that the population means for two groups are equal.
#
# Given:
# - Group 1: mean (\(\bar{x}_1\)) = 80, std dev (s1) = 10, n1 = p 2: mean (\(\bar{x}_2\)) = 75, std dev (s2) = 8, n2 = 40
# - Significance level ( = 80
# std_dev1 = 10
# n1 = 30
#
# mean2 = 75
# std_dev2 = 8
# n2 = 40
#
# alpha = 0.01
#
# # Calculate pooled standard deviation
# pooled_std_dev = (((n1 - 1) * stdstd_dev2 ** 2) / (n1 + n2 - 2)) ** 0.5
# standar/ n1 + 1 / n2) ** t-statistic
# t_statistic = (mean1 - mean2) / standard_error
# # Calculatgrees of freedom
# df = n1 + n2 - 2
# # Calculate p-value
# p_value = stats.
# abs(t_statistic), df=df) * 2
#
# t_statistic, p_value
# ```
#
# If the p-value is less than \(\alpha\), we reject the null hypothesis.
#
# ### Q17: Estimate the populatio a 99% confidence interval.
#
# Given:
# - Sample mean (\(\bar{x}\)) = 4
# - Sample standard deviation (s) = 1.5
# - Sample size (n) = 50
#
# ```python
# sample_mean = 4
# sample_std_dev = 1.5
# sample_size = 50
# confidence_level = 0.99
# alpha = 1 - confidence_level
#
# t_critical = stats.t.ppf(1 - alpha/2, df=sample_size-1)
# standard_error = sample_std_dev / (sample_size ** 0.m.422, 4.578) \]
#
# These answers cover the concepts of estimation, hypothesis testing, and the application of statistical methods to various scenarios using Python.
