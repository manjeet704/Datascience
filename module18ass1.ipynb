# %% [markdown]
# # Q1. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation of 5 using Python. Interpret the results.
#
# To calculate the confidence interval, we'll use the formula for the confidence interval of a normal distribution:
#
# \[ CI = \bar{x} \pm Z \left(\frac{\sigma}{\sqrt{n}}\right) \]
#
# Where:
# - \(\bar{x}\) is the sample mean.
# - \(Z\) is the Z-score corresponding to the confidence level (for 95%, \(Z \approx 1.96\)).
# - \(\sigma\) is the sample standard deviation.
# - \(n\) is the sample size.
#
# Since the sample size is not given, we'll assume a large sample size where the population standard deviation can be approximated by the sample standaon.
#
# ```python
# import scipy.stats as stats
# inp
#
# # Given values
# mean = 50
# std_dev = 5
#  the 95% confidence level
# z_score = stats.norm.ppf(1 - (1) is approximated as std_dev
# margin_# Calculate confidence interval
# confidence_interval = (mean - margin_of_error, mean + margf_r)
# confidence_interval
# ```
#
# ### Q2. Conduct a chi-square goodness of fit test to determine if the distribution of colors of M&Ms in a bag matches the expected distribution of 20% blue, 20% orange, 20% green, 10% yellow, 10% red, and 20% brown. Use Python to perform the test with a significance level of 0.05.
#
# We'll assume som frequencies for this test.
#
# ```pre
#
# # Observed frequencies (example data)
# obsted frequencies based on the given proportions
# e
#
# # Perform the chi-square goodness of fit test
# chi2_statistic, p_value = chisquare(f_obs=observed_frequencies, f=ted_frequencies)
# chi2_statistic, p_value
# ```
#
# ### Q3. Use Python to calculate the chi-square statistic and p-value for a contingency table. Interpret the results of the test.
#
# Assuming the contingency table data is given:
#
# |          | Outcome 1 | Outcome 2 |
# |----------|-----------|-----------|
# | Group A  | 20        | 15        |
# | Group B  | | 25        |
# | Group C  | 15        | 20        |
#
# ```python
# import pandas as pd
# from scipy.stats import chi2_contingency
#
# # Cont0, 15],
#         [10, 25],
#         [15, 20]]
#
# # Convert to a DataFrame
# contingency_table = pd.DataFrame(data, col], index=["Group A", "Group B", "Group C"])
#
# # Perform the chi-square test
# chiatval, dof, ex = chi2_contingency(contingency_table)
# chi2_stat, p_val
# ```
#
# ### Q4. Calculate the 95% confidence interval for the true proportion of individuals in the population who smoke.
#
# Given:
# - Total population = 500
# - Number of smokers = 60
#
# We'll use the formula for the confidence interval for a proportion:
#
# \[ CI = \hat{p} \pm Z \sqrt{\frac{\hat{p}(1 - \hat \(\hat{p}\) is the sample proportion.
# - \(n\)
#
# ```python
# # Given values
# total_populatio
#
# # Sample proportion
# p_hat = number_of_smokers / total_populat = np.sqrt(p_hat * (1 - p_hat) / total_populatfor the 95% confidence level
# z_score = stat
# # Calculate the margin of error
# margin_of_error = z_score * standard_error
#
# # Calculate i interval
# confidence_interval = (p_hat - margin_of_error, p_hat + margin_of_error)
# confidence_interval
# ```
#
# ### Q5. Calculate the 90% confidence interval for a sample of data with a mean of 75 and a standard deviatnterpret the results.
#
# We'll use the same formython
# # Given values
# mean = 75
# std_dev = 12
# confidencedence_level) / 2)
#
# # Assuming a larrd error is simply std_dev/sqrt(n) is approximated as std_dev
# margin_of_error = z_score * sd
# # Calculate confidence interval
# confidence_interval = (mean - margin_of_error, mean + margin_of_error)
# confidence_interval
# ```
#
# ### Q6. Use Python to plotquare distribution with 10 degrees of freedom. Label the axes and shade the area i-square s```python
# import matplotlib.pyplot as plt
# importrt chi2
#
# # Degrees of freedom
# df = 10
#
# # Chi-square values
# x = np.linspace(0, 30, 1000)
# y = chi2.pdf(x, df)
#
# # Plot ribution
# plt.plot(x, y, label='Chi-square distribution (df=10)')
# plt.fill_between(x, 0, y, where=(x <= 15), color='gray', alpha=0.5)
#
# # Labels and title
# plt.xlabel('Chi-square statistic')
# plt.ylabel('Probability density')
# pltli-square Distribution with 10 Degrees of Freedom')
# plt.axvline(x=15, color='r', linestyle='--', label='Chi-square stat = 15')
# plt.legend()
# plt.show()
# ```
#
# ### Q7. A random sample of 1000 people was asked if they preferred Coke or Pepsi. Of the sample, 520 preferred Coke. Calculate a 99% confidence interval for the true proportion of people in the population who prefer Coke.
#
# Given:
# - Total samplf people who preferred Coke = 520
#
# We'll use tonfidence interval for a proportion as in Q4 .
#
# ```python
# # Given values
# sample_size = 1000
# number_prmber_preferred_coke / sample_size
#
# # Calculaerror = np.sqrt(p_hat * (1 - p_hat) / samplee for the 99% confidence level
# z_score = stats.norm.ppf(1 - (1 - 0.99) / 2)
#
# # Calculate tarof error
# margin_of_error = z_score * standard_error
#
# # Calculate confidence interval
# confidence_interval = (p_hat - margin_of_error, p_hat + margin_of_error)
# confidence_interval
# ```
#
# ### Q8. Conduct a chi-square goodness of fit test to determine if the observed frequencies match the ex. Use a significance level of 0.lips = 100
# - Observed tails = 45ected proportion for tails = 0.5
#
# ```python
# # Observed frequencies
# observed_frequencies = [45, 55]
#
# # Expectedques
# expected_frequencies = [50, 50]
#
# # Perform the chi-square goodness of fit test
# chi2_statistic, p_value = chisquare(f_obs=observed_frequencies, f_exp=expected_frequencies)
# chi2
#
# |              | Lung Cancer: Yes | Lung Cancer: No |
# |--------------|------------------|-----------------|| **Smer**   | 60               | 140
# | **Non-ser** | 30             | 170             |
#
# We'll perform the chi-square test using Ppendence
#
# The chi-square test for independence examines whether there is a significant association between two categorical variables. The test statistic is calculated as follows:
#
# \[ \chi^2 = \sum \frac{(O_i - E_i)^2}{E_i} \]
#
# Where:
# - \(O_i\) are the observed frequencies.
# - \(E_i\) are the expected frequencies, calculated as \(E_i = \frac{(row\ total \times column\ total)}{grand\ total}\).
#
# Let's he test:
#
# ```python
# import pandas as pd
# from scipy.stats imate the contingency table
# data = [[60, 140], [30, 170]]
# contingency_table = pd.DataFrame(data, columns=["Lung Cancer: Yes", "Lung Cancer: No"], index-square test for independence
# chi2_stat, p_val, dof, ex = chi2_contingency(contingency_tabl``
#
# ## Interpretation of Results
#
# 1**Chi-square statistic (\(\chi^2\))**: This measures how much the observed frequencies devia from t expected frequencies.
# 2. **p-value**: This indicates the probability of obtaining the observed data (or more extreme) assuming the null hypothesis is true. The null hypothesis for the chi-square test of independence states tt the variables are indendent.
# 3. **Degrees of freedom (dof)**: This is calculated as \((\text{number of rows} - 1) \time(\text{number of columns} 1)\).
# 4. **Expected frequencies (ex)**: These are the frequencies we would expect if the null hypothesis were true.
#
# If the p-value is less than the significance level (0.05), we reject the null hypothesis and conclude that there is a significant association between se code and interpret the results.
#
# ```python
# import pandas chi2_contingency
#
# # Create the contingency table
# data = [[60, 140], [30, 170]]
# contingency_table = pd.DataFrame(data, columns=["Lung Cancer: Yes", r"])
#
# # Perform the chi-square test for independence
# chi2_stat, p_val, dof, ex = chi2_conbl
# chi2_stat, p_val, dof, ex
# ```
# ### Interpretation
#
# - **Chi-sq statisc (\(\chi^2\))**: The test statistic calculated.
# - **p-value**: Iis value is less than 0., we reject the null hypothesis.
# - **Degree freedom (dof)**: Number  degrees of freedom in the test.
# - **Expected frequencies (ex)**: Expected counts if the variables are independent.
# ode and interpret the results.
#
# ## Interption ofesults
#
# Chi-square statistic (\(hi^2*: 12.057
# - **p-value**:.00052
# - **Degrees of freedom (dof)**: 1
# - **Expected frequencies (ex)**:
#   - For smokers with lung cancer: 45
#   - For smokers without lung cancer: 155
#   - For no provides strong evidence that smoking status is related to lung cancer diagnosis.nogency(data)
# chi2_stat, p_val
# ```
#
# For each of these tests, you can run the Python code in your environment to obtain the specific results. The interpretations will be based on the significance levels and the calculated statistics.

# %% [markdown]
# Q10. Chi-Square Test for Independence (Chocolate Preference and Country of Origin)
# 's conduct a chi-square test for independence to determine if there is a significant association between chocolate preference (milk chocolate, dark chocolate, white chocolate) and country of origin (U.S. vs U.K.) using a significance level of 0.01.
#
# The contingency table is given as:
#
# |                | Milk Chocolate | Dark Chocolate | White Chocolate |
# |----------------|----------------|----------------|---------------|
# *U.S.**       | 200            | 150            | 150           |
#  **U.K.**       | 225            | 175            | 100
#
# ```python
# import pandas as pd
# from scipy.stats import chContingency table
# data = [[200, 150, 150],
#       onvert to a DataFrame
# contingency_table = pd.DataFrame(data, columns=["Milk Chocolate", "Dark Chocolate", "White Chocolate"], inre test for independence
# chi2_stat, p_val, dof, ex = chi2_contingency(contingency_table)
#
# Chi-square statistic (\(\chi^2\)): 13.39
# p-value: 0.00123
# Degrees of freedom (dof): 2
# Expected frequencies (ex):
#   - U.S.: Milk Chocolate: 212.5, Dark Chocolate: 162.5, White Chocolate: 125
#   - U.K.: Milk Chocolate: 212.5, Dark Chocolate: 162.5, White Chocolate: 125
# i2t, p_val, dof, ex
# ```
#
# ### Q11. Hypothesis Test for Population Mean
#
# Given:
# - Sample size (\(n\)) = 30
# - Sample mean (\(\bar{x}\)) = 72
# - Sample standard deviation (\(s\)) = 10
# - Population mean (\(\mu_0\)) = 70 (under the null hypothesis)
#
# We will conduct a one-sample t-test to determine if the population mean is significantly different from 70 using a significance level of 0.05.
#
# The test statistic for the t-test is calculated as follows:
#
# \[ t = \frac{\bar{x} - \mu_0}{s / \sqrt{n}} \]
#
# Where:
# - \(\bar{x}\) is the sample mean.
# - \(\mu_0\) is the population mean under the null hypothesis.
# - \(s\) is the sample standard deviation.
# - \(n\) is the sample size.
#
# We will compare the calculated t-statistic to the critical t-value from the  of freedom.
#
# ### Performin
# ```python
# import scipy.stats as stats
#
# # Given values
# sample_mean = 72
# population_mean = 70
# same = 30
# significance_level = 0.05
#
# # Calculate the t-statistic
# t_stat = (sample_m) / (sample_std_dev / (ple_size - 1
#
# # Calculate the critical t-value for a two-= stats.t.ppf(1 - significance_level / 2, dof)
#
# # Calculate the p-value
# p_val= (1 - stats.t.cdf(abs(t_stat), dof)) * 2
#
# t_stat, t_critical, p_valueol 70. The sample mean of 72 is not significantly different from the hypothesized population mean of 70.
