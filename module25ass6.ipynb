# %% [markdown]
# Download the wine dataset from the UCI Machine Learning Repository: Wine Dataset.
# Load the dataset into a Pandas DataFrame.
# Data Preprocessing
#
# Split the dataset into features (independent variables) and the target variable (dependent variable).
# Perform data preprocessing, including:
# Scaling: Use StandardScaler from scikit-learn to standardize features by removing the mean and scaling to unit variance.
# Normalization: If needed, apply normalization to scale the data between 0 and 1.
# Missing Value Imputation: If there are any missing values (although the wine dataset does not have any), handle them appropriately (e.g., using mean imputation).
# Implement PCA
#
# Use PCA from the scikit-learn library to reduce the dimensionality of the dataset.
# Determine the optimal number of principal components to retain based on the explained variance ratio.
# Visualize PCA Results
#
# Create a scatter plot to visualize the PCA-transformed data. Use the first two principal components for visualization.
# Color the scatter plot points based on their target class.
# Perform Clustering on PCA-Transformed Data
#
# Use the K-Means clustering algorithm to cluster the PCA-transformed data.
# Visualize the clustering results on the scatter plot.
# Interpret Results
#
# Analyze the results of PCA to understand the variance explained by the selected principal components.
# Evaluate the performance of the K-Means clustering algorithm using metrics such as inertia, silhouette score, etc.
# Discuss any patterns or insights observed from the PCA and clustering results.
# Prepare Deliverables
#
# Jupyter Notebook: Include all the code and outputs in a Jupyter notebook.
# Report: Summarize the results of the PCA and clustering analysis.
# Scatter Plot: Include the plot visualizing the PCA results and clustering analysis.
# Performance Metrics Table: Provide a table showing the performance metrics for the clustering algorithm.
#
# import pandas as pd
# import numpy as np
# from sklearn.preprocessing import StandardScaler
# from sklearn.decomposition import PCA
# from sklearn.cluster import KMeans
# import matplotlib.pyplot as plt
# import seaborn e dataset
# url = "https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data"
# column_names = ['Alcohol', 'Malic_acid', 'Ash', 'Alcalinity_of_ash', 'Magnesium',
#                 'Total_phenols', 'Flavanoids', 'Nonflavanoid_phenols', 'Proanthocyanins',
#                 'Color_intensity', 'Hue', 'OD280/OD315_of_diluted_wines', 'Proline']
# df = pd.read_csv(url, header=None, names=['Class'] +  target variable
# X = df.drop('Class', axis=1)g
# # Scaling the data
# scaler = StandardScaler()
# X_scaled = s
# # Step 4: Implement PCA
# pca = PCA(n_components=2)
# X_pca = p
#
# # Explained variance ratio
# explained_variance = pca.explained_variance_ratio_
# print(f"Explained variance ratio by principal comp
# # Step 5: Visualize PCA Results
# plt.figure(figsize=(8,6))
# sns.scatterplot(x=X_pca[:,0], y=X_pca[:,1], hue=y, palette='Set1')
# plt.title('PCA of Wine Dataset')
# plt.xlabel('Principal Component 1')
# plt.ylabeerform Clustering on PCA-Transformed Data
# kmeans = KMeans(n_clusters=3)
# kmeans.fedict(X_pca)
#
# # Visualize Clustering Results
# plt.figure(figsize=(8,6))
# sns.scatterplot(x=X_pca[:,0], y=X_pca[:,1], hue=y_kmeans, palette='Set2')
# plt.title('K-Means Clustering on PCA-Transformed Data')
# plt.xlabel('Principal Component 1t Results
# # Evaluate clustering performance (optional)
# from sklearn.metrics import silhouette_score
# silhouette_avg = silhouette_score(X_pca, y_kmeans)
# print(f'Si
# PCA Implementation: We use two principal components for visualization, but you can determine the optimal number by plotting cumulative explained variance.
# K-Means Clustering: We chose 3 clusters since the original dataset has 3 classes. Adjust the number of clusters based on your analysis.
# Visualizations: Scatter plots are used for both PCA results and clustering results.
# Performance Metrics: Include metrics like silhouette score to evaluate clustering quality.
# Deliverables Summary
# Jupyter Notebook: Include the above code and any additional code used for preprocessing, PCA, or clustering.
# Report: A concise document discussing:
# The choice of preprocessing techniques.
# The rationale behind selecting the number of principal components.
# Observations from the scatter plot and clustering analysis.
# Any insights or patterns identified in the PCA-transformed data.
# Scatter Plot: Include visualizations within the notebook and report.
# Clustering Performance Table: Summarize clustering performance metrics.lhouette Score for K-Means clustering: {silhouette_avg}')
