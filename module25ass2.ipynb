# %% [markdown]
# ### Q1. Implementing the KNN Classifier on the `load_iris` Datasthon
# from sklearn.datasets import load_iris
# from sklearn.model_selection import train_test_split
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.metrics import accurache dataset
# iris = load_iris()
# X = iris.data
# y nd testing sets
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, lassifier with k=3
# knn_classifier = KNeighborsClassif to the training data
# knn_classifier.Predict on the test data
# y_pred = knn_cla accuracy of the classifier
# accuracy = accuracy_score(y_test, y_pred)
#
# print(f'Accuracy of KNN Classr:{accuracy * 100:.2f}%')
# ```
#
# ### Q2. Implementing the KNN Regres `load_boston` Dataset
#
# ```python
# from sklearn.datasets import load_boston
# from sklearn.model_selection import train_test_split
# from sklearn.neighbors import KNeighborsRegressor
# from skl mean_squared_error
#
# # Load the dataset
# boston = load_blit the dataset into training and testing sets
# X_train, X_test, y_train, y_test = train_tete=42)
#
# # Initialize the KNN regressor with k=3
# kneighbors=3)
#
# # Fit the model to thsor.fit(X_train, y_train)
#
# # Predict ost)
#
# # Calculate the Mean Squared Error pint(f'Mean Squared Error of KNN Regressor: {mse:.2f}')
# ```
#
# ### Q3. Finding the Optimal Value of K for the Kier using Cross-Validation on the `load_iris` Dataset
#
# ```python
# from sklearn.datasets import load_iris
# from sklearn.model_selection import cross_val_score
# from sklearn.nighborsClassifier
# import matplotlib.pyplot as plts = load_iris()
# X = iris.data
# y = iringe(1, 26)
# cv_scores = []
#
# # Perform 10-fold cross-validation for each k value
# for k in k_values:
#     knn_classifier = KNeighborsClassifier(n_neighbors=k)
#     scores = cross_val_score(k cv_scores.append(scores.mean())
#
# # Plot the cross-validation scores against k values
# plt.plot(k_values, cv_scores, marker='o')
# plt.xlabel('Number of Neigh-Validation Accuracy')
# plt.title('Optimal K Value')
# plt.show()
#
# # Find the optimal k value
# optimal_ values[cv_scores.index(max(cv_scores))]
# print(f'The optimal value of K is: {optimal_k}'### Q4. Implementing the KNN Regressor with Feature Scaling on the `load_boston` Dataset
#
# ```python
# from sklearn.datasets import load_boston
# from sklearn.model_selection import train_test_split
# from sklearn.neighbors import KNeighborsRegressor
# from skleaport StandardScaler
# from sklearn.metrics import mean_squa
# boston = load_boston()
# X = boston.data
# y = boston.target
#
# # Split the dataset into trts
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#
# # Scale the featurcaled = scaler.fit_transform(X_train)
# X_test_scaledthe KNN regressor with k=3
# knn_regressor =
#
# # Fit the model to the scaled training dataedict on the scaled test data
# y_pred = knn_regressor.predict(X_test_scaled)
#
# # Calculate the Mean Squaree metric.
#
# These code snippets provide a foundation for implementing and tuning KNN classifiers and regressors in Python using scikit-learn.

# %% [markdown]
# ### Q5. Implementing the KNN Classifier with Weighted Voting on the `load_iris` Datasethon
# from sklearn.datasets import load_iris
# from sklearn.model_selection import train_test_split
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.metrics import accurache dataset
# iris = load_iris()
# X = iris.data
# y =nd testing sets
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, rstance ('distance')
# knn_classifier = KNeighborsClassifier(n_neighbors=3, l to the training data
# knn_classifier Predict on the test data
# y_pred = knn_ce accuracy of the classifier
# accuracy = accuracy_score(y_test, y_pred)
#
# print(f'Accuracy of KNN Classifier with Weighted Vn {accuracy * 100:.2f}%')
# ```
#
# ### Q6. Implementing a Function to Standardize the FeaturApplying KNN Classifier
#
# ```python
# from sklearn.preprocessing import StandardScaler
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import accuracy_score
# from sklearn.datasets import load_iris
#
# def standardize_and_knn(X, y, n_neighbors=3):
#     # Standardize the features
#     scaler = StandardScaler(Split the dataset into training and testing sets
#     X_train, X_test, y_train, y_test = train_test_split(tate=42)
#
#     # Initialize the KNN classifier
#     knn_classifier hbors)
#
#     # Fit the model to the tt(X_train, y_train)
#
#     # Predict on t_test)
#
#     # Calculate the accuracy of the classifier
#     accurac(y_test, y_pred)
#
#     return accuracy
#
# # Lis.data
# y = iris.target
#
# # Call the function and print the accuracy
# accuracy = standardize_and_knn(X, y)
# t('Accuracy of Standardized KNN Classifier: {accuracy * 100:.2f}%')
# ```
#
# ### Q7. Impl Function to Calculate the Euclidean Distance Between Two Poio points.
#     Points should be provided as tuples, lists, or numpy arrays.
#     """
#     point1 = np.array(point1)
#     point2 = np.arrdistance = np.sqrt(np.sum((point1 - point2) ** 2))
#     return distance
#
# # Example usage
# p1 = [1, 2, 3]
# p2 =
# 56]
# distance = euclidean_distance(p1, p2)
# print(f'Euclidean Distance: {distance:.2f}'### Q8. Implementing a Function to Calculate the Manhattan Distance Between Two Points
#
# ```python
# import numpy as np
#
# def manhattan_distance(point1, point2):
#     """
#     Calculate the Manhattan distance between two points.
#     Points should be provided as tuples, lists, or numpy arrays.
#     """
#     point1 = np.arraoint2 = np.array(point2)
#     distance = np.sum(np.abs(point1 - point2))
#     return distance
#
# # Example usage
# e you a solid foundation for working with KNN and understanding different aspects of distance metrics and data preprocessing.
