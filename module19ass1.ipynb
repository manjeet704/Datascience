# %% [markdown]
# Q1: Define overfitting and underfitting in machine learning. What are the consequences of each, and how can they be mitigated?
# **Overfitti** **Definitn**: Overfitting occurs when a machine learning model learns the training data too well, including its noise and outliers. As a result, the model performs very well on the training data but poorly on unseen test dat- **Consequees**:
#   - Poor generalization to new data.
#   - High variance: Model predictions vary significantly for different data.
# - **Mitation**:
#   - Use more training data.
#   - Apply regularization techniques (e.g., L1, L2 regularization).
#   - Prune the model (e.g., reduce the depth of decision trees).
#   - Use cross-validation to tune model parameters.
#   - Simplify e model.
#
# Un**Definition**: Underfitting occurs when a machine learning model is too simple to capture the underlying patterns in the data. It performs poorly on both the training test data.
# **Consequences**:
#   - Poor model performance.
#   - High bias: Model makes strong assumptions and fails to capture the comple of the da.
# - **Mitigation**:
#   - Increase model complexity (e.g., use a more complex model or add more features).
#   - Reduce regularization.
#   - Improve the feature engineering process.
#   - Train the modor a longer time.
#
# ### Q2: How can we reduce overfittin Explain in brf.
#
# **Regularization**:
#    -*L1 Regularization (Lasso)**: Adds a penalty equal to the absolute value of the maude of coefficients.
#    **L2 Regularization (Ridge)**: Adds a penalty equal to the square of the maitude of coefficnts.
#
# 2. **Cross-Validation**:
#    - Use techniques like k-fold cross-validation to ensure the model generizes we to unseen data.
#
# 3. **Pruning**:
#    - For decision trees, limit the depth of the tree or remove nos that provideittle power.
#
# 4. **Early Stopping**:
#    - Monitor the performance on a validation set and stop training when t performance stas to degrade.
#
# 5. **Ensemble Methods**:
#    - Use methods like bagging, boosting, or scking timprove model robustness.
#
# 6. **Dropout** (for neural networks):
#    - Randomly drop neurons during training to prevent the network from beming too reliant  specific neurons.
#
# 7. **Data Augmentation**:
#    - Increase the size and variability of the training dataset by applying transformationch as rotations, translations, and flips.
#
# ### Q3: Explain underfitting. Lisscenarios whe rfitting c occur in ML.
#
# **Underfitting**:
# - **Definition**: Underfitting occurs when a model is too simplistic to capture the underlying trends in the data, resulting in po performance on both training and testatase.
#
# **Scenarios where underfitting can cur**:
# 1. **Using a Linear Model for Non-Linear Data**:
#    - Applying a linear regressiomodel to data that s a non-linear relationship.
#
# 2. **High Regularization**:
#    - Applying too much regularization (e.g., high lambda in  regularization), whi overly constrains the model.
#
# 3. **Insufficient Training**:   - Training a model fotoo few epochs or iterations.
#
# 4. **Poor Feature Engineering**:
#    - Using an inadequate number of features or featus that do not capturthe underlying patterns of the data.
#
# 5. **Oversimplified Model**:
#    - Using a model with very few parars, such as a shallow decision tree or a small neural network.
#
# ### Q4: Explain the bias-variance tradeoff in machine learning. What is the relationship tween bias and varianc aow dthey affect model performance?
#
# **Bias-Variance Tradeoff**:
# - **Bias**: The error introduced by approximating a real-world problem, which may be complex, by a simplified model. High bias can cause the model to mislevant rations between features and target outputs (underfitting).
# - **Variance**: The error introduced by the model's sensitivity to small fluctuations in the training set. High variance can causehe model to dee random noise in the trning data (overfitting).
#
# **Relationship**:
# - **High Bias (Underfitting)**:
#   - Model is too simple.
#   - High training error angh validation error.
#   - Pr performance on both training and test data.
#
# - **High Variance (Overfitting)**:
#   - Model is too complex.
#   - Low training error and high validati error.
#   - Good performan oaining data b poor performance on test data.
#
# **Effect on Model Performance**:
# - **Optimal Model**:
#   - Achieves a nce between bias and variance.
#   - Good performance on both training and test data.
#
# ### Q5: Discuss some common methods for detecting overfitting and underfitting in machineearning models. How can you determine whether yourodel ioverfitting or underfitting?
# **Met for Detectg Overfitting and Underfitting**:
#
# 1. **Training Validation Cves**:
#    - **Overfitting**: Low training error and gh validation err.
#    - **Underfitting**: High training error and high validation error.
#
# 2. **Cross-Validation**:
#    - Evaluate model performance using k-fold cross-lidation. Largeifferences between training and cross-validation scores indicate overfitting.
#
# 3. **Learning Curves**:
#    - Plot training and valition errors as function of training size. Analyze the convergence and divergence of the curves.
#
# 4. **Residual Plots**:
#    - For regression problems, analyze the residuals (differencetween observed and predicted values). Patterns in residuals can indicate underfitting or overfitting.
#
# ### Q6: Compare and contrast bias and variance in machine learning. What areome am of high bs and high variance models, and how do they differ in terms of their perance?
# **Bias**:
# - **Definition**: Error due to oy simplistic assptions in the learning algorithm.
# - **Effect**: Leads to systemac error  pctions.
# -*High Bias Models**: Linear regression, logistic regression with too features
#
# **Variance**:
# - **Definition**: Error due tositivity to small fltuations in the training data.
# - **Effect**: Leads to overfitting and poor generalizion.
# - **Hh ance Models**: Dision trees with high depth, neural networks with too many layers and  rons.
#
# **Performan**:
# - **High Bias Models**:
#   - High training and validation error.
#   - Undting the data.
# - **High Variance Models**:
#   - Low training error but high validation error.
#   - Overfitting the data.
#
# ### Q7: What is regularization in macne learning, a h to prevent overfitting? Describe some common regularization techniques and how they woron**A technique used to preve overfitting by adding a penalty to the model's complexity.
#
# **Common Regularization Techniques**:
#
# 1. **L1 Regularization (Lasso)**:
#    - Adds a penalty equal to the absolute value of t magnitude of coefficient
#    - Encourages sparsity, driving some coefficients to zero, effectively performing feature selection.
#
# 2. **L2 Regularization (Ridge)**:
#    - Adds a palty equal  the square of the magnitude of coefficients.
#    - Encourages smaller coefficients, reducing the complexity of the model.
# 3. **Elastic Net**:
#    - A mbination of L1 and L2 regularization.
#    - Balances between the effects of Lasso and Ridge regularization.
#
# 4. **Dropout (for Neural Networks)**:
#    - Randomly drops neurons during training torevent the netrk from becoming too reliant on specific neurons.
#    - Helps in reducing overfitting by ensuring that neurg when performance starts to degrade.
#
# Regularization helps in controlling the complexity of the model, thus improving its generalization to unseen data.
