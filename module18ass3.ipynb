# %% [markdown]
# Q1: Python function to calculate F-value and p-value for a variance ratio testhon
# from scipy import stats
#
# def variance_ratio_test(data1, datadatasets
#     var1 = np.var(data1, ddof=1)
#     var2 = np.var(data2, ddof=1)ue
#     F_value = var1 / var2 if var1 > var2 else varof freedom
#     df1 = len(data1) - 1
#     df2 = lene p-value
#     p_value = 2 * min(stats.f.cdf(F_value, df1, df2), 1 - stats.f.cdf(F_value, ddf2))
#
#     return F
#
# # Example usage
# data1 = [24, 25, 28, 23, 22, 20, 27]
# data2 = [31, 33, 35, 30, 32, 36]
# F_value, p_value = variance_ratio_test(data1, data2)
# print(f"F-value: {F_value}: {p_value}")
# ```
#
# ### Q2: Python function to return the critical F-vatwo-tailed test
#
# ```python
# def critic    al_f_value(alpha, dfn, dfd):
#     # Two-tailed test
#     alpha = alpha / 2
#     F_critical_low = stats.f.ppf(alpha, dfn, dfd)
#     F_critical_high = stats.f.ppf(1 - alpha, dfn, dfd)
#     retu, F_critical_high
#
# # Example usage
# alpha = 0.05
# dfn = 6
# dfd = 7
# F_critical_low, F_critical_high = critical_f_value(alpha, dfn, dfd)
# print(f"Critical F-valu{Ftical_low}, {F_critical_high}")
# ```
#
# ### Q3: Python program to gedom samples and perform an F-test
#
# ```python
# import numpy as np
# from scipy import stats
#
# def generate_samvar1, var2, n1, n2):
#     # Generate random samples
#     sample1 = np.random.normal(mean1, np.sqrt(var1), n1)
#     sampqrt(var2), n2)
#
#     # Perform variance ratio test
#     F_value, p_value = variance_ratio_test(sample1, sample2)
#     dfn = n1 - - 1
#     return F_value, dfn, dfd, p_value
#
# # Example usage
# mean1, mean2 = 0, 0
# var1, var2 = 10, 15
# n1, n2 = 12, 12
# F_value, dfn, dfd, p_value = generate_samples_and_f_test(mean1, mean2, var1, var2, n1, n2)
# print(vue: {p_value}")
# ```
#
# ### Q4: F-test for known variances
#
# ```python
# def f_test_known_variances(var1, var2, n1, n2, alpha):
#     F_value = var1 / var2 if var1 > var2 else var2 / var1
#     dfn = n1 - 1
#     dfd = n2 - 1
#     p_value = 2 * min(stats.f.cdf(F_value, dfn, dfd), 1 - stats.f.cdf(F_value, dfn, dfd))
#     F_critical_low, F_critical_high = critical_f_value(a
#     return F_value, p_value, F_critical_low, F_critical_high
#
# # Example usage
# var1, var2 = 10, 15
# n1, n2 = 12, 12
# alpha = 0.05
# F_value, p_value, F_critical_low, F_critical_high = f_test_known_variances(var1, var2, n1, n2, alpha)
# print(f"F-value: {Futh specific questions or need more detailed explanations for any part, feel free to ask!

# %% [markdown]
# Q4.The variances of two populations are known to be 10 and 15. A sample of 12 observations is taken from
# each population. Conduct an F-test at the 5% significance level to determine if the variances are
# significantly differents import f
#
# # Given data
# var1 = 10
# var2 = 15
# = 0.05
#
# # Calculate the F-value
# F_value = var1 / var2 if var1 > var2 else var2fd = n2 - 1
#
# # Calculate the p-value
# p_value = 2 * min(f.cdf(F_value, dfe critical F-values for a two-tailed test
# F_critical_low, F_critical_high = f.ppf(alpha / 2, 1 - alpha / 2, dfn, dfd)
#
# # Output results
# print(f"F-value: {F_value}")
# print(f"p-value: {p_value}")
# print(f"Critical F-values: {F_critical_low}, {F_critical_high}")
# print("Reject null hypothesis" if p_value
# Q5. A manufacturer claims that the variance of the diameter of a certain product is 0.005. A sample of 25
# products is taken, and the sample variance is found to be 0.006. Conduct an F-test at the 1% significance
# level to determine if the claim is justified.
# nufacturer's variance claim
#
# ```python
# # Given data
# claimed_variannce = 0.006
# n = 25
# alpha = 0.01
#
# # Calculaue = sample_variance / clees of freedom
# dfn = n - 1
# dfd = ne, dfn, dfd)
#
# # Determine the critical -tailed test
# F_critical = f.ppf(1 - alpha, dfn, dfd)
#
# # Output results
# print(f"F-value: {F_value}")
# print(f"p-value: {p_value}")
# print(f"Critical F-value: {F_critical}")
# print("Reject nul
# Q6. Write a Python function that takes in the degrees of freedom for the numerator and denominator of an
# F-distribution and calculates the mean and variance of the distribution. The function should return the
# mean and variance as a tuple.
# : Python function to calculate mean and variance of an F-distribution
#
# ```python
# def f_distribution_mean_variance(dfn, dfd):
#     mean = dfd / (dfd - 2) if dfd > 2 else float('inf')
#     variance = 2 * (dfd**2) * (dfn + dfd - 2) / (d * (dfd - 4)) if dfd > 4 else float('inf')
#     return mean, variance
#
# # Example usage
# dfn, dfd = 5, 10
# mean, varia Q7. A random sample of 10 measurements is taken from a normal population with unknown variance. The
# sample variance is found to be 25. Another random sample of 15 measurements is taken from another
# normal population with unknown variance, and the sample variance is found to be 20. Conduct an F-test
# at the 10% significance level to determine if the variances are significantly different.
# ce}")
# ```
#
# ### Q7: F-test for unknown variances```python
# # Given data
# var1 = 25
# var2 = 20
# n1 = 10
# n2 = 15
# alpha = 0.10
#
#
# F_value = var1 / var2 if var1 > var2 else var2 / var1
# dfn = n1 - 1
# dfd = cdf(F_value, dfn, dfd), 1 - f.cdf(F_value, dfn, dfd))
#
# # Determine the critical F-values fort
# F_critical_low, F_critical_high = f.ppf(alpha / 2, dfn, dfd), f.ppf(1 - alpha / 2, dfn, dfd)
#
# # Output results
# print(f"F-value: {F_value}")
# print(f"p-value: {p_value}")
# print(f"Critical F-values: {F_critic
# Q8. The following data represent the waiting times in minutes at two different restaurants on a Saturday
# night: Restaurant A: 24, 25, 28, 23, 22, 20, 27; Restaurant B: 31, 33, 35, 30, 32, 36. Conduct an F-test at the 5%
# significance level to determine if the variances are significantly different.
# else "Fail to reject null hypothesis")
# ```
#
# ### Q8: F-test for waiting times at twohon
# # Given data
# data_A = [24, 25, 28, 23, 22, 20, 27]
# data_ 36]
# alpha = 0.05
#
# # Calculate variances
# var_A = np.var(data_A, ddof=1)
# var_B = np.var(data_B, ddof=value
# F_value = var_A / var_B if var_A > var_B else var_B / var_A
# dfn = l p-value
# p_value = 2 * min(f.cdf(F_value, dfn, dfd), 1 - f.cdf(F_value, dfn, dfd))
#
# # Determ F-values for a two-tailed test
# F_critical_low, F_critical_high = f.ppf(alpha / 2, dfn, dfd), f.ppf(1 - alpha / 2, dfn, dfd)
#
# # Output results
# print(f"F-value: {F_value}")
# print(f"p-value: {p_value}")
# printriQ9. The following data represent the test scores of two groups of students: Group A: 80, 85, 90, 92, 87, 83;
# Group B: 75, 78, 82, 79, 81, 84. Conduct an F-test at the 1% significance level to determine if the variances
# are significantly different.
# import numpy as np
# from scipy.stats import resis" if p_value < alpha else "Fail to reject null hypothesis")
# ```
#
# ### Q9: F-tetwo groups of students
#
# ```python
# # Given data
# group_A = [80,oup_B = [75, 78, 82, 79, 81, 84]
# alpha = 0.01
#
# # Calculate variances
# var_A = np.var(group_A, ddof=1)
# vdof=1)
#
# # Calculate the F-value
# F_value = var_A / var_B if var_A > var_Broup_B) - 1
#
# # Calculate the p-value
# p_value = 2 * min(f.cdf(F_value, dfn, dfd), 1 - f.cdf())
#
# # Determine the critical F-values for a two-tailed test
# F_critical_low, F_critical_high = f.ppf(alpha / 2, dfn, dfd), f.ppf(1 - alpha / 2, dfn, dfd)
#
# # Output results
# print(f"F-value: {F_value}")
# print(ions. Each code snippet calculates the F-value, p-value, and critical F-values, and then determines whether to reject the null hypothesis based on the p-value and significance level.
