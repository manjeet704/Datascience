# %% [markdown]
# Q1. Explain the difference between simple linear regression and multiple linear regression. Provide an
# example of each. regression?
#  A statistical method used to model the relationship between a single independent variable (X) and a dependent variable (Y).
# Example: Predicting house prices based solely on the size of the house (square footage).
# Multiple Linear Regression
# Definition: A statistical method used to model the relationship between multiple independent variables (X1, X2, X3, ...) and a dependent variable (Y).
# Example: Predicting house prices based on multiple factors like size, number of bedrooms, location, and age.
# Key difference: Simple linear regression uses one independent variable, while multiple linear regression uses two
# Q2. Discuss the assumptions of linear regression. How can you check whether these assumptions hold in
# a given dataset?
# hecking Them
# Linear regression makes several assumptions about the data:
#
# Linearity: The relationship between the dependent and independent variables is linear.
# Normality: The residuals (errors) are normally distributed.
# Homoscedasticity: The variance of the residuals is constant across all values of the independent variable.
# Independence: The observations are independent of each other.
# No multicollinearity: The independent variables are not highly correlated with each other.
# To check these assumptions:
#
# Linearity: Plot the residuals against the fitted values. A random pattern indicates linearity.
# Normality: Use histograms, Q-Q plots, or statistical tests like the Shapiro-Wilk test.
# Homoscedasticity: Plot the residuals against the fitted values. Look for a constant spread of points.
# Independence: Check if data points are collected randomly and independently.
# Multicollinearity: Calculate correlation coefficients between independent variables or use Variance Inflation Fa
# Q3. How do you interpret the slope and intercept in a linear regression model? Provide an example using
# a real-world scenario.
# nd Intercept
# Slope
# Represents the change in the dependent variable (Y) for a one-unit change in the independent variable (X).
# Example: If the slope of a regression model predicting house prices based on size is 200, it means that for every additional square foot, the house price increases by $200.
# Intercept
# Represents the predicted value of the dependent variable (Y) when the independent variable (X) is zero.
# Example: In the house price example, the intercept would be the predicted price of a house with zero square footage, which might not have a real-world inte
# Q4. Explain the concept of gradient descent. How is it used in machine learning?ient Descent
# Definition: An optimization algorithm used to find the minimum of a function.
# Machine Learning: Used to find the optimal parameters (weights and biases) of a model by minimizing the cost function (error).
# Process: Iteratively adjusts parameters in the direction of steepest descent to reach the lowest point on the error
# Q5. Describe the multiple linear regression model. How does it differ from simple linear regression?
# r Regression
# Definition: A statistical method used to model the relationship between multiple independent variables (X1, X2, X3, ...) and a dependent variable (Y).
# Difference from Simple Linear Regression: Uses more than one independent variable to predict the dependent variable, allowing for more complex relationships and potentially better pred
# Q6. Explain the concept of multicollinearity in multiple linear regression. How can you detect and
# address this issue?
# collinearity
# Definition: Occurs when two or more independent variables in a regression model are highly correlated.
# Detection: Correlation matrix, VIF, or tolerance.
# Addressing: Remove one of the correlated variables, combine correlated variables, or use techniques like Principal Component Anal
# Q7. Describe the polynomial regression model. How is it different from linear regression?l Regression
# Definition: A form of regression analysis in which the relationship between the independent variable (X) and the dependent variable (Y) is modeled as an nth-degree polynomial.
# Difference from Linear Regression: Allows for more complex relationships between variables, capturing non-linea
# Q8. What are the advantages and disadvantages of polynomial regression compared to linear
# regression? In what situations would you prefer to use polynomial regression?l Regression
# Advantages
# Can capture complex relationships that linear regression cannot.
# Better fit for non-linear data.
# Disadvantages
# Overfitting can occur if the degree of the polynomial is too high.
# Interpretation of coefficients can be difficult.
# When to Use
# When the relationship between variables is clearly non-linear.
# When linear regression fails to capture the underlying pattern.
# Be cautious about overfitting and use techniques like cross-validation to assess model performance.
