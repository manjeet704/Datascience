# %% [markdown]
# Q1. What is the mathematical formula for a linear SVM?
# Linear SVM attempts to find a hyperplane that best separates data points of different classes. The equation of this hyperplane is given by:
#
# w^T * x + b = 0
# Where:
#
# w is the weight vector perpendicular to the hyperplane
# x is the input data point
# b is the bias term
#
# Q2. What is the objective function of a linear SVM?
# The objective function of a linear SVM aims to maximize the margin between the hyperplane and the closest data points (support vectors) from both classes. This can be formulated as:
#
# Maximize: margin = 2 / ||w||
# Subject to: yi(w^T * xi + b) >= 1 for all i
# Where:
#
# yi is the class label (+1 or -1)
# xi is the i-th data point
#
# Q3. What is the kernel trick in SVM?
# The kernel trick is a mathematical technique used to implicitly map data into a higher-dimensional space without explicitly calculating the coordinates. This allows SVMs to handle non-linearly separable data. Common kernels include:
#
# Linear kernel: For linearly separable data.
# Polynomial kernel: For data with polynomial relationships.
# Radial Basis Function (RBF) kernel: For non-linear relationships.
#
# Q4. What is the role of support vectors in SVM? Explain with example.
# Support vectors are the data points that lie closest to the hyperplane. They are crucial in determining the position and orientation of the hyperplane.
#
# Influence on the hyperplane: Support vectors directly influence the calculation of the weight vector w and the bias term b.
# Sparsity: Only support vectors are needed for making predictions, making SVMs efficient.
# Example: Consider a dataset of emails labeled as spam or not spam. The support vectors would be the emails that are most difficult to classify, lying closest to the decision boundary.
#
# Q5. Illustrate with examples and graphs of Hyperplane, Marginal plane, Soft margin and Hard margin in SVM?
# Hyperplane and Marginal Planes
# Hyperplane: The decision boundary that separates data points into different classes.
# Marginal planes: Two parallel hyperplanes that pass through the closest data points (support vectors) on either side of the hyperplane.
# Opens in a new window
# medium.com
# hyperplane and marginal planes in SVM
# Soft Margin and Hard Margin
# Hard margin: Assumes data is perfectly linearly separable, maximizing the distance between the hyperplane and the nearest data points.
# Soft margin: Allows for some misclassification by introducing a penalty term in the objective function, making it more flexible for real-world data.
# [Image comparing hard margin and soft margin SVMs]
#
# Note: The graphical representation of hyperplanes, marginal planes, and margins is typically shown in two-dimensional space for simplicity. However, in real-world applications, data often exists in higher-dimensional spaces.

# %% [markdown]
# Q6. SVM Implementation through Iris dataset.
#
# Bonus task: Implement a linear SVM classifier from scratch using Python and compare its
# performance with the scikit-learn implementation.
# ~ Load the iris dataset from the scikit-learn library and split it into a training set and a testing setl
# ~ Train a linear SVM classifier on the training set and predict the labels for the testing setl
# ~ Compute the accuracy of the model on the testing setl
# ~ Plot the decision boundaries of the trained model using two of the featuresl
# ~ Try different values of the regularisation parameter C and see how it affects the performance of
#
#
# To implement and evaluate a linear SVM classifier on the Iris dataset, follow these steps:
# thon
# import numpy as np
# import pandas as pd
# from sklearn import datasets
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler
# from sklearn.svm import SVC
# from sklearn.metrics import accuracy_score
# import matplotlib.pyplot as plt
# from matplotlib.colors import ListedColormap
#
# # Load the Iris dataset
# iris = datasets.load_iris()
# X = iris.dataes for visualizationraining and testing sets
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_si)
#
# # Standardize features
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_te. **Using Scikit-learn**
#
# ```python
# # Train a linear SVM classifier
# linear_svm = SVC(kernel='linear', C=1.0, random_statin)
#
# # Predict labels on the testinsvm.predict(X_test)
#
# # Compute the accuracy
# accuracy = accuracy_score(y_test, y_pred)
# print(f"Accuracic implementation using gradient descent:
#
# ```python
# class LinearSVM:
#     def __init__(self, C=1.0, learning_rate=0.01, num_iterations=1000):
#         self.C = C
#         self.learning_rate = learning_rate
#         self.num_iterations = num_iterations
#
#     def fit(self, X, y):
#         num_samples, num_features = X.shape
#         self.W = np.zeros(num_features)
#         self.b = 0
#
#         # Convert y to +1, -1
#         y = np.where(y == 0, -1, y)
#
#         for _ in range(self.num_iterations):
#             for i in range(num_samples):
#                 if y[i] * (np.dot(X[i], self.W) + self.b) < 1:
#                     self.W += self.learning_rate * (y[i] * X[i] - 2 * self.C * self.W)
#                     self.b += self.learning_rate * y[i]
#                 else:
#                     self.W -= self.learning_rate * 2 * self.C * self.W
#
#       return np.sign(np.dot(X, self.W) + self.b)
#
# # Train the custom LinearSVM
# custom_svm = LinearSVM(tions=1000)
# custom_svm.fit(X_train, y_trainn the testing set
# y_pred_custom = custom_svm.predict(X_test)
#
# # Compute the accuracy
# accuracy_custom = accuracy_scordecision boundaries, create a mesh grid and plot the regions for different classes.
#
# ```python
# def plot_decision_boundary(clf, X, y, title):
#     h = .02  # step size in the mesh
#     x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
#     y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
#     xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
#
#     Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
#     Z = Z.reshape(xx.shape)
#
#     plt.contourf(xx, yy, Z, alpha=0.8, cmap=ListedColormap(['#FFAAAA', '#AAAAFF', '#AAFFAA']))
#     plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', marker='o', cmap=ListedColormap(['#FF0000', '#0000FF' plt.ylabel('Feature 2')
#     plt.title(title)
#     plt.show()
#
# # Plot decision boundaries for scot decision boundaries for custom SVM
# # Custom SVM must be refitted with the data scaled to nt with Different Values of Regularization Parameter \(C\)
#
# ```python
# # Train and evaluate SVM with different values of C
# C_values = [0.01, 0.1, 1, 10, 100]
# for C in C_values:
#     svm = SVC(kernel='linear', C=C, random_state=42)
#     svm.fit(X_train, y_train)
# egularization parameter \(C\).
#
# These steps cover the implementation, evaluation, and comparison of a linear SVM model on the Iris dataset.the model.
