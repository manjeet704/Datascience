# %% [markdown]
# Q1, Create a vehicle class with an init method having instance variables as name_of_vehicle, max_speed
# and average_of_vehicle
#
# class Vehicle:
#     def __init__(self, name_of_vehicle, max_speed, average_of_vehicle):
#         self.name_of_vehicle = name_of_vehicle
#         self.max_speed = max_speed
#         self.average_of_vehicle = average_of_veh usage
# car = Vehicle("Toyota Corolla", 180, 15)
# print(f"Name of Vehicle: {car.name_of_vehicle}")
# print(f"Max Speed: {car.max_speed} km/h")
# print(f"Average: {car.average_of_vehicle} km/l")
# ...

# %% [markdown]
# Q2. Create a child class car from the vehicle class created in Que 1, which will inherit the vehicle class.
# Create a method named seating_capacity which takes capacity as an argument and returns the name of
# the vehicle and its seating capacity.
# class Vehicle:
#     def __init__(self, name_of_vehicle, max_speed, average_of_vehicle):
#         self.name_of_vehicle = name_of_vehicle
#         self.max_speed = max_speed
#         self.average_of_vehicle = average_of_vm Vehicle
# class Car(Vehicle):
#     def seating_capacity(self, capacity):
#         return f"The {self.name_of_vehicle} has a seating capacity of { Example usage
# car = Car("Toyota Corolla", 180, 15)
# print(f"Name of Vehicle: {car.name_of_vehicle}")
# print(f"Max Speed: {car.max_speed} km/h")
# print(f"Average: {car.average_of_vehicle} km/l")
# print(car.seating_capacity(5))

# %% [markdown]
# Q3. What is multiple inheritance? Write a python code to demonstrate multiple inheritance.
# Multiple inheritance is a feature in object-oriented programming where a class can inherit attributes and methods from more than one parent class. This allows the child class to inherit and combine the behaviors of multiple parent classes.
# class Engine:
#     def __init__(self, engine_type):
#         self.engine_type = engine_type
#
#     def start_engine(self):
#         return f"Starting {self.engine_type} en class 2
# class Transmission:
#     def __init__(self, transmission_type):
#         self.transmission_type = transmission_type
#
#     def change_gear(self, gear):
#         return f"Changing to gear {gear} with {self.transmission_type} and Transmission
# class Car(Engine, Transmission):
#     def __init__(self, name_of_vehicle, engine_type, transmission_type):
#         Engine.__init__(self, engine_type)
#         Transmission.__init__(self, transmission_type)
#         self.name_of_vehicle = name_of_vehicle
#
#     def display_info(self):
#         return f"{self.name_of_vehicle} with

# %% [markdown]
# Q4. What are getter and setter in python? Create a class and create a getter and a setter method in this
# class
#
# In Python, getters and setters are methods used to access and modify the private attributes of a class. They provide a way to encapsulate the access to an attribute, ensuring that the attribute is not directly accessed or modified from outside the class. This helps to maintain the integrity and control over how the attributes are accessed and modified.
#
# Getter: A method used to get the value of an attribute.
# Setter: A method used to set the value of an attribute.
#
# class Student:
#     def __init__(self, name, age):
#         self._name = namete
#         self._age = ageute
#
#     # Getter method for name
#     @property
#     def name(self):
#         return self._name
#
#     # Setter method for name
#     @name.setter
#     def name(self, name):
#         if isinstance(name, str):
#             self._name = name
#         else:
#             raise ValueError("Name must be a string")
#
#     # Getter method for age
#     @property
#     def age(self):
#         return self._age
#
#     # Setter method for age
#     @age.setter
#     def age(self, age):
#         if isinstance(age, int) and age > 0:
#             self._age = age
#         else:
#             raise ValueError("Age n instance of the StManjeet kumarass
# 5stoe", 20)
#
# # Using gt(student.name)  # Oue# Output: 20
#
# #Suramya mishraetter methods
# s25dent.name = "Jane Doe"
#
# print(student.name)Jses ValueError: Age must be a positive integer
# .

# %% [markdown]
# Q5.What is method overriding in python? Write a python code to demonstrate method overriding.
# Method overriding in Python occurs when a child class provides a specific implementation of a method that is already defined in its parent class. The method in the child class overrides the method in the parent class. This allows the child class to provide a specific implementation for the method that is more suited to its needs.
#
# class Animal:
#     def sound(self):
#         return "Some generic animal sound"
#
# # Child class
# class Dog(Animal):
#     def sound(self):
#         return "Bark"
#
# # Another child class
# class Cat(Animal):
#     def sound(self):
#         return "Meow"
#
# # Create instances of each class
# generic_animal = Animal()
# dog = Dhod on each instance
# print(gene generic animal sound
# print(dog        # Output: Bark
# print(ca         # Output: Meow
