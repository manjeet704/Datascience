# %% [markdown]
# Q1. Pearson correlation coefficient is a measure of the linear relationship between two variables. Suppose
# you have collected data on the amount of time students spend studying for an exam and their final exam
# scores. Calculate the Pearson correlation coefficient between these two variables and interpret the resulttwvariable
#
# **Datase:**
# - `study_time[2, 3, 5, 7 9]
# - `exam_scores`: [hon Code:**
#
# ```python
# import numpy as np
# from scrt pearsonr
#
# # Sample data
# study_time = [2, 3, 5, 7, 9]
# exam_ Pearson correlation coefficient
# pearson_corr, _ = pearsonr(study_time, exam_scores)
# print("Pearson correlanefficient:", peson_corr)
# ```
#
# **Interpretation:**
# - The Pearson correlation coefficient ranges from -1 to 1.
# - A value of 1 implies a perfect positive linear relationship.
# - A value of -1 implies a perfect negative linear relationship.
# - A value of 0 implies no linear relationship.
#
# Given the above data, if the Pearson correlation coefficient is close to 1, it indicates that as the amount of study time increases, exam scores also tend to increase, show
# Q2. Spearman's rank correlation is a measure of the monotonic relationship between two variables.
# Suppose you have collected data on the amount of sleep individuals get each night and their overall job
# satisfaction level on a scale of 1 to 10. Calculate the Spearman's rank correlation between these two
# variables and interpret the result.
# rlation bw sleep and ob satisfaction
#
# Dataset:**
# - `seep_hours`: [7, 8, n`: [8, 9, 7, 10, 6]
#
# **Python Cothon
# from scipy.stats import spearmanr
#
# # Sample data
# sleep_hou0, 6]
#
# # Calculate Spearman's rank correlation coefficient
# spearman_corr, _ = spearmanr(sleep_hours, job_satisfaction)
# priarman's rank coelation coefficient:", spearman_corr)
# ```
#
# **Interpretation:**
# - The Spearman correlation coefficient also ranges from -1 to 1.
# - A value of 1 implies a perfect positive monotonic relationship.
# - A value of -1 implies a perfect negative monotonic relationship.
# - A value of 0 implies no monotonic relationship.
#
# If the Spearman correlation coefficient is close to 1, it indicates that as the amount of sleep increases, job satisfaction als
# Q3. Suppose you are conducting a study to examine the relationship between the number of hours of
# exercise per week and body mass index (BMI) in a sample of adults. You collected data on both variables
# for 50 participants. Calculate the Pearson correlation coefficient and the Spearman's rank correlation
# between these two variables and compare the results.
#
#
# # Q3: Pesand Spearman crrelation between exercise hours and BMI
# *Daaset:**
# - `exercise_hours`: [2, 3, 5, 7, 9, ..i`: [25, 24, 22, 21, 20, ..., (total 50 values)]
#
# **Python Codimport pearsonr, spearmanr
#
# # Sample data (only a few values are shown for brevit, 50)
# bmi = np.random.uniform(18, 30, 50)
#
# # Calculate Pearson correlation coefficient
# pearson_corr, rrelation coefficient:", pearson_corr)
#
# # Calculate Spearman's rank correlation coefficient
# spearman_corr, _ = sp(exercise_hoursbmi)
# print("Spearman's rank correlation coefficient:", spearman_corr)
# ```
#
# **Interpretation:**
# - If both the Pearson and Spearman correlation coefficients are negative, it indicates an inverse relationship between exercise hours and BMI. The stronger the negative value, the stronger the relationship.
# - Pearson correlation assesses linear relationships, while Spearman correlation assesses monotonic relationships.
# - CQ4. A researcher is interested in examining the relationship between the number of hours individuals
# spend watching television per day and their level of physical activity. The researcher collected data on
# both variables from a sample of 50 participants. Calculate the Pearson correlation coefficient between
# these two variables.t'simply moic.
#
# ## Q4: Pearson correlation coefficient betw TV hours and phyical activity
#
# **Dataset:**
# - `tv_hours`: [1 values)]
# - `physical_activity`: [30, 25, 20, 15, 10on
# import numpy as np
# from scipy.stats import pearsonr
#
# # Sample data (only a few valueom.randint(1, 10, 50)
# physical_activity = np.random.uniform(10, 60, 50)
#
# # Calculate Pearson correlation coeff
# pearson_corr, = pearsonr(tv_hours, physical_activity)
# print("Pearson correlation coefficient:", pearson_corr)
# ```
#
# **Interpretation:**
# - A negative Pearson correlation coefficient would indicate that as the number of TV hours incrvalues for the correlation coefficients, allowing you to interpret the strength and direction of the relationships in each case.

# %% [markdown]
# Q5. A survey was conducted to examine the relationship between age and preference for a particular
# brand of soft drink. The survey results are shown below:
# import pandas as pd
# ta
# data = {'Age': [25, 42, 37, 19, 31, 28],
#         'Preference': ['Coke', 'Pepsi', 'Mountain Dew', 'Coke', 'Pepsi', 'Coke']}
#
# df = pd.DataFrame(Encoding
# df_encoded = pd.get_dummies(df, columns=['Preference'])
# print("One-Hot Encoded Data:")
# print(de correlation
# correlation_matrix = df_encoded.corr()
# print("\nCorrelation Matrix:")
# print(corr
# The correlation matrix will show how strongly age is correlated with each soft drink preference. Positive values indicate a positive relationship, while negative values indicate a negative relationship. Values close to 0 indicate a weak or no relationship.elation_matrix)
# w
# Coke
# Pepsi
# Coke

# %% [markdown]
# Q6. A company is interested in examining the relationship between the number of sales calls made per day
# and the number of sales made per week. The company collected data on both variables from a sample of
# 30 sales representatives. Calculate the Pearson correlation coefficient between these two variable
#
# import numpy as np
# import pandas as pd
# from scipy.stats import pearsontion
# np.random.seed(0)  # For reproducibitatives
# sales_calls_per_day = np.random.randint(10, 50, 30)
# sales_per_week = sales_calls_per_day + np.random.normal(0, 5, 30)  # Adding soa DataFrame
# df = pd.DataFrame({
#     'Sales_Calls_Per_Day': sales_calls_per_day,
#     'Sales_Per_Week': sale
# # Print the data
# print("Sample rrelation coefficient
# correlation, _ = pearsonr(df['Sales_Calls_Per_Day'], df['Sales_Per_Week'])
#
# print(f'\nPearson correlation coeff
# The Pearson correlation coefficient will range between -1 and 1:
#
# A value of 1 indicates a perfect positive linear relationship.
# A value of -1 indicates a perfect negative linear relationship.
# A value of 0 indicates no linear relationship.icient: {correlation}')
# s.
